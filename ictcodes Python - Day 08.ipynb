# %% [markdown]
# ![4253515.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #Task 01: [Recode Mark Calculator]:
# Maximum Marks: 80
#
# Enter Marks: 93
#
# "Error"

# %%
name=input("Enter your Name: ")
n=int(input("Enter Number of Subjects: "))
m=int(input("Enter Maximum Marks in one Subject: "))

flag=0
total=0
mark = []

for x in range(n):
  p=float(input("Enter Marks: "))
  if(p>m):
    print("Marks Should Not be Greater than ",m)
    flag=1
    break    
  mark.append(p)
  total=total+mark[x]


average = total/n
percentage=(total/(m*n))*100

if(flag==0):
  print("\n\nHello ",name)
  print("Your Marks are ",mark)
  print("\n\nTotal Mark = ", total)
  print("Average Mark = ",average)
  print("Percentage = ",percentage,"%")

# %% [markdown]
# # Task 02: Write a Lambda Function for Simple Interest Calculator
# P
#
# N
#
# R
#
# I=PNR

# %%
p=float(input("Enter P"))
n=float(input("Enter N"))
r=float(input("Enter R"))

si = lambda x,y,z : x*y*z

print("Interest = ",si(p,n,r))
# Out:
# Enter P10000
# Enter N5
# Enter R0.08
# Interest =  4000.0

# %% [markdown]
# #Task 03: Denominations Finder
# Input an Amount and Compute How many Currency Denomenations are needed

# %%
#Denominations Finder

n=int(input("Enter an Amount: "))

print("Denominations are ")

print("2000 x ",n//2000)
n=n%2000

print("500 x ",n//500)
n=n%500

print("200 x ",n//200)
n=n%200

print("100 x ",n//100)
n=n%100

print("50 x ",n//50)
n=n%50

print("20 x ",n//20)
n=n%20

print("10 x ",n//10)
n=n%10

print("5 x ",n//5)
n=n%5

print("2 x ",n//2)
n=n%2

print("1 x ",n)

# %% [markdown]
# #Strings

# %%
a = "Hello"
b = 'Hello'
c = """Hello"""

i = "Hello, I'm Ashikh Ahamed"
q = 'she told me "you are a fool"'
#Multiline Strings
p = """My Name is "Ashikh", 
I'm a Python Programmer"""


print(a)
print(b)
print(c)
print(i)
print(q)
print(p)
# Out:
# Hello
# Hello
# Hello
# Hello, I'm Ashikh Ahamed
# she told me "you are a fool"
# My Name is "Ashikh",
# I'm a Python Programmer

# %% [markdown]
# #Slicing of Strings

# %%
a="Hello World!"
print(a[4])

print(a[-2])

print(a[0:7])
# Out:
# o
# d
# Hello W

# %% [markdown]
# #String Length

# %%
k="Welcome"

print(len(k))
# Out:
# 7

# %% [markdown]
# #String Methods (Functions)

# %%
#The strip() method removes any whitespace from the beginning or the end:
a="   Hello World!   "
print(a.strip())

#Upper
print(a.upper())

#Lower
print(a.lower())

b="Hello Good Morning to All, I hope you are fine"

#String Replace
print(b.replace('o','b'))

#String Concatenation
print(a+b)
# Out:
# Hello World!
#    HELLO WORLD!
#    hello world!
# Hellb Gbbd Mbrning tb All, I hbpe ybu are fine
#    Hello World!   Hello Good Morning to All, I hope you are fine

# %% [markdown]
# #Escape Character
#
# ## \n --> New Line
# ## \\ --> BackSlash
# ## \' --> Single Quotes
# ## \t --> Tab

# %%
print("He\tllo World!")
# Out:
# He	llo World!

# %% [markdown]
# #Task : Reverse a String
#
# ##Enter a string: "ASHIKH"
# ## HKIHSA

# %% [markdown]
# # Task: Count the Number of Wovels in a String
#
# ## Enter a String: "Hello, Iam Ashikh"
# ## 6
