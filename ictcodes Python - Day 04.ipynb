# %% [markdown]
# ![4253515.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # KSEB Electricity Bill Calculator
# ![image.png](data:image/png;base64,...)

# %%
type=input("Enter S for Single Phase and T for 3 Phase: ")
x=float(input("Enter Usage: "))

if type=='S':
  fixed=70
elif type=='T':
  fixed=140
else:
  print("Invalid Option")

if x<100:
  amount=x*6
elif x<200:
  amount=x*6.7
elif x<300:
  amount=x*7.4
elif x<500:
  amount=x*8
else:
  amount=x*9.30

bill=amount+fixed

print("Your Total Bill Amount is : ",bill)
# Out:
# Enter S for Single Phase and T for 3 Phase: T
# Enter Usage: 80
# Your Total Bill Amount is :  620.0

# %% [markdown]
# #Loops
# Almost all the programming languages provide a concept called loop, which helps in executing one or more statements up to a desired number of times.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## while loop
# With the while loop we can execute a set of statements as long as a condition is true.

# %%
# While Loop Syntax
# initialize the loop control variable
# while (condition):
# loop body with increment of loop control variable


i=1
while i<=100:
  print(i)
  i=i+1

# %% [markdown]
# #Shorthand Operators
#
# i+=1 --> i=i+1

# %% [markdown]
# # break Statement
# With the break statement we can stop the loop even if the while condition is true:

# %%
i=1
while i<10:
  print(i)
  if(i==5):
    break
  i=i+1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# #continue statement
# With the continue statement we can stop the current iteration, and continue with the next:

# %%
i = 0
while i < 6:
  i += 1
  if i == 3:
    continue
  print(i)
# Out:
# 1
# 2
# 4
# 5
# 6

# %% [markdown]
# #else statement
# With the else statement we can run a block of code once when the condition no longer is true.

# %%
i = 1
while i < 6:
  print(i)
  i += 1
else:
  print("i is no longer less than 6")
# Out:
# 1
# 2
# 3
# 4
# 5
# i is no longer less than 6

# %%
i=1
while i<100:
  print(i)
  i+=2
else:
  print("Loop Completed...")

# %% [markdown]
# #Multiplication Table

# %%
n=int(input("Enter a Number"))

a=1
while a<11:
  print(n," x ",a," = ",n*a)
  a=a+1
# Out:
# Enter a Number11
# 11  x  1  =  11
# 11  x  2  =  22
# 11  x  3  =  33
# 11  x  4  =  44
# 11  x  5  =  55
# 11  x  6  =  66
# 11  x  7  =  77
# 11  x  8  =  88
# 11  x  9  =  99
# 11  x  10  =  110

# %%
n=int(input("Enter a Number: "))

k=1
while k<=10:
  print(n," x ",k," = ",n*k)
  k=k+1
# Out:
# Enter a Number: 5
# 5  x  1  =  5
# 5  x  2  =  10
# 5  x  3  =  15
# 5  x  4  =  20
# 5  x  5  =  25
# 5  x  6  =  30
# 5  x  7  =  35
# 5  x  8  =  40
# 5  x  9  =  45
# 5  x  10  =  50

# %% [markdown]
# # Task 1: Find Sum of numbers upto n
# eg: 5 --> (1+2+3+4+5) = 15

# %%
# Input

#loop initiate 

#body babu= babu + x

# print(babu)

# %% [markdown]
# # Task 02:  Find the Factorial of a Number
#
# eg: 5 --> (1x2x3x4x5) = 120

# %%
#write your code here

# %% [markdown]
# #for loop
#
# A for loop is used for iterating over a sequence

# %%
for x in range(6):
  print(x)

# %%
for x in range(2, 6):
  print(x)

# %%
for x in range(2, 30, 3):
  print(x)
